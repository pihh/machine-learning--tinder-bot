# %%
from src.tinder import TinderApi
# Out:
# press enter once you logged in
# r_new <Response [200]>
# inited

# %%
api = TinderApi(verbose=False)
# Out:
# Login response: {'meta': {'status': 200}, 'data': {'_id': '63bc1c319773ba01004a2c5d', 'api_token': 'c2379dae-9f47-4a68-8c0c-81eba235091a', 'refresh_token': 'eyJhbGciOiJIUzI1NiJ9.MTAxNTM5MzU0MDk5ODA2MTg.X4CLARfiZVYJtnjz7SltpJqFRxhhg9DAw63j8k9HoKE', 'is_new_user': False}}
# My coordinates: [38.679, -9.1569]

# %%
api.get_photos()
#for i in range(10):api.get_photos()
# Out:
# ['https://images-ssl.gotinder.com/u/pDRrzvXJtM774wb6SUvyhH/cGah7sgjGBFZXkyewygTyn.jpg?Policy=eyJTdGF0ZW1lbnQiOiBbeyJSZXNvdXJjZSI6IiovdS9wRFJyenZYSnRNNzc0d2I2U1V2eWhILyoiLCJDb25kaXRpb24iOnsiRGF0ZUxlc3NUaGFuIjp7IkFXUzpFcG9jaFRpbWUiOjE2ODc2NzYzNTN9fX1dfQ__&Signature=G2RwGsDbl0abU70E6cLPjuUoA7SuLL7puX95bTw3pmvxeADHRsWD2RYmfgqIKy~1qI-yd~GNG-ELubU1Bp3bqILh6c5-TRpJ6bodeob-quZnq1SE3zWzJq52YepTxGaXnubkLWAj6oGugRA3axvC7ni-njah6bpJIKsj9r2OLLScWSzrAfziIoMB6UW0f10HIt8s2coLWVzOXZ~OTdjtff3ZnaIlnNYopGXpcxpiyOgaFI4BRL-9-Dyx3qST~sqned1t9m7Ar-O0szYfsa-JXmsQp-DhG8vL9OpjMYI4s~JB8nfzNMNu5zviy8ZVaP6xfjpL3dNcC1oVH5oD8xhh2Q__&Key-Pair-Id=K368TLDEUPA6OI',
# ...
